# %% [markdown]
# # Capstone Project
#
# This notebook explores the HMDA dataset for 2024.
# We begin by loading and inspecting the data.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 9.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 16.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 8.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348 kB 11.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("data/2024_ts.txt", sep="|")
df.head()
# Out:
#    activity_year  calendar_quarter                   lei      tax_id  \
# 0           2024                 4  01KWVG908KE7RKPTNP46  91-1299114
# 1           2024                 4  549300CG5TM73650DH84  95-1981100
# 2           2024                 4  254900IHSG9OOX0DZH92  91-0684272
# 3           2024                 4  984500A9F1AADF548748  20-8780109
# 4           2024                 4  549300LL0P3NQ5Q2UF60  95-0944725
#
#    agency_code                    respondent_name respondent_state  \
# 0            3                    HomeStreet Bank               WA
# 1            5   Christian Community Credit Union               CA
# 2            5        NORTHWEST PLUS CREDIT UNION               WA
# 3            7        Commercial Loan Corporation               CA
# 4            5  Long Beach Firemen's Credit Union               CA
#
#   respondent_city respondent_zip_code  lar_count
# 0         Seattle               98101       2396
# ...

# %%
df.shape
# Out:
# (4926, 10)

# %%
df_lar = pd.read_csv(
    "data/2024_lar.txt",
    sep="|",
nrows=100000  # solo muestra

)

df_lar.head()
# Out:
# /var/folders/9h/m28081695mj6xck0r_jgj72c0000gn/T/ipykernel_73156/2736493853.py:1: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lar = pd.read_csv(
#    activity_year                   lei  derived_msa_md state_code  \
# 0           2024  549300K4ZLGS7SRDTL86           99999         PA
# 1           2024  549300K4ZLGS7SRDTL86           29460         FL
# 2           2024  549300K4ZLGS7SRDTL86           28700         VA
# 3           2024  549300K4ZLGS7SRDTL86           26420         TX
# 4           2024  549300K4ZLGS7SRDTL86           33460         MN
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0      42107.0  4.210700e+10                     C            FHA:First Lien
# 1      12105.0  1.210501e+10                     C            FHA:First Lien
# 2      51191.0  5.119101e+10                     C             VA:First Lien
# ...
